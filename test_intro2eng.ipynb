% %% [markdown]
% # CHAPTER TEST
% ## This is a test for a small plotting lesson
%
% This is a plot of the $sin$ function
%
% $$
% f(x) = \frac{\sin(x)}{x}
% $$

% %%
% Let's try plotting this function from 0 to 200
x = 0:200;
y = sin(x)./x;
plot(x,y)
